# %%
import os
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import tensorflow as tf 
import math

def mkMonthData():

    daybyday = pd.read_csv("./data/Regular_Season_Batter_Day_by_Day.csv")
    daybyday['1B'] = daybyday['H'] - daybyday['2B'] - daybyday['3B'] - daybyday['HR']
    for i in ['opposing_team','SB','CS']:
        del daybyday[i]
    sub = pd.read_csv("./data/submission.csv")
    # sub 파일에 없는 선수 걸러내기
    dayNamelist=list(daybyday["batter_name"].unique())
    subNameslist= list(set(sub['batter_name']))

    namelist=[]
    for i in dayNamelist:
        if i in subNameslist:
            namelist+=[i]

    delrow=[]
    for i in range(len(daybyday)):
        if daybyday["batter_name"][i] in namelist:
            continue
        else:
            delrow+=[i]
    daybyday = daybyday.drop(delrow,0)
    month = pd.DataFrame(columns=('batter_id', 'batter_name','year', 'month', 'am_avg','avg', 'AB', 'R', 'H', '1B', '2B', '3B','HR', 'RBI', 'BB', 'HBP', 'SO', 'GDP'))
    idx=0
    for n in namelist:
        a=daybyday.loc[daybyday["batter_name"]==n,]
        year=sorted(list(a['year'].unique()))
        for y in year:
            b=a.loc[a["year"]==y,]
            for i in range(3,11):
                c=b.loc[b["date"]//1==i,]
                if len(c):
                    state=list(c[['avg2', 'AB', 'R', 'H', '1B', '2B', '3B','HR', 'RBI', 'BB', 'HBP', 'SO', 'GDP']].sum(axis=0))
                    state[0]=c["avg2"].iloc[-1]
                    if state[1]:
                        avg1=round(state[3]/state[1],3)
                    else:
                        avg1=0
                    state=[c["batter_id"].iloc[0],n,y,i]+[avg1]+state
                    month.loc[idx]=state
                    idx+=1
    BABIP=[]
    SLG=[]
    OBP=[]
    for i in range(len(month)):
        if (month['H'][i] - month['HR'][i]) and (month['AB'][i] - month['SO'][i] -month['HR'][i]):
            BABIP+= [round((month['H'][i] - month['HR'][i]) / (month['AB'][i] - month['SO'][i] -month['HR'][i]),3)]
        else:
            BABIP+=[0]
            
        if (month['1B'][i] + month['2B'][i] + month['3B'][i] + month['HR'][i]) and (month['AB'][i]):
            SLG+= [round((month['1B'][i] + 2*month['2B'][i] + 3*month['3B'][i] + 4*month['HR'][i]) / (month['AB'][i]),3)]
        else:
            SLG+=[0]   
            
        if (month['H'][i] + month['BB'][i] + month['HBP'][i]) and (month['AB'][i] + month['BB'][i] + month['HBP'][i]):
            OBP+= [round((month['H'][i] + month['BB'][i] + month['HBP'][i]) / (month['AB'][i] + month['BB'][i] + month['HBP'][i]),3)]
        else:
            OBP+=[0] 
            
    month['BABIP']=BABIP
    month['SLG']=SLG
    month['OBP']=OBP

    mean=[]
    for c in range(3):
        mean.append([])
        
    for i in range(len(namelist)):
        a=month.loc[month["batter_name"]==namelist[i],][["BABIP",'SLG','OBP']].values
        for j in range(len(a)):
            for c in range(3):
                if j==0:
                    mean[c]+=[a[0][c]]
                else:
                    mean[c]+=[round((a[j][c]+(mean[c][j-1]*j))/(j+1),3)]
                    
    for idx,col in enumerate(["BABIP",'SLG','OBP']):
        month["am_"+col]=mean[idx]

    return month

# ======== corre_OPS Functions
def get_BABIP(alist):
    BABIP = 0
    if (alist['H'] - alist['HR']) and (alist['AB'] - alist['SO'] - alist['HR']):
        BABIP+= round((alist['H'] - alist['HR']) / (alist['AB'] - alist['SO'] -alist['HR']),3)
    return BABIP

def get_OPS_model(reg_batterFile):

    seed = 0
    np.random.seed(seed)
    tf.set_random_seed(seed)

    id_arr = reg_batterFile['batter_id'].unique()
    id_arr = id_arr.tolist()

    main_col = [
            'avg','AB','R','H',
            '2B','3B','HR','RBI','BB',
            'HBP','SO','GDP','SLG',
            'OBP'
            ]

    alist = []

    for bat_id in id_arr:
        nptf = reg_batterFile.loc[reg_batterFile['batter_id'] == bat_id]
        nptf = nptf.fillna(0)
        recentData = nptf.iloc[-1]
        recentData['BABIP'] = get_BABIP(recentData)
        extract_data = []
        extract_data.append(recentData['BABIP'])
        for col in main_col:
            if recentData[col] == '-':
                recentData[col] = 0
            extract_data.append(recentData[col])
        
        alist.append(extract_data)

    df = pd.DataFrame(alist)
    dataset = df.values

    X = dataset[:,:14]
    Y = dataset[:,14]

    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=seed)

    modelOPS = Sequential()
    modelOPS.add( Dense(30, input_dim=14, activation='relu') )
    modelOPS.add( Dense(6, activation='relu') )
    modelOPS.add( Dense(1) )

    modelOPS.compile(loss='mean_squared_error',
                    optimizer='adam')


    modelOPS.fit(X_train, Y_train, epochs=200, batch_size=10)


    return modelOPS


# ========= Predict each col Functions
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i + look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

def predcit_next_DBD(nptf, column, look_back=1):
    
    # normalization
    scaler = MinMaxScaler(feature_range=(0, 1))
    nptf = nptf[column].values
    nptf = nptf.reshape(-1,1)
    nptf = scaler.fit_transform(nptf)

    train_size = int(len(nptf) * 0.9)
    test_size = len(nptf) - train_size
    train, test = nptf[0:train_size], nptf[train_size:len(nptf)]

    # create dataset for learning
    trainX, trainY = create_dataset(train, look_back)
    testX, testY = create_dataset(test, look_back)
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
    
    # simple lstm network learning
    model = Sequential()
    model.add(LSTM(8, input_shape=(1, look_back)))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(trainX, trainY, epochs=5, batch_size=1, verbose=2)

    
    # 향후 10달의 평균 예측
    look_ahead = 10
    res = nptf.copy()
    res = create_dataset(res,1)
    res = res[0]

    res = np.reshape(res, (res.shape[0], 1, res.shape[1]))
    pre = model.predict(res)
    res = np.append(res, [[pre[-1]]])
    res = np.reshape(res, (res.shape[0], 1))

    for _ in range(look_ahead):
        res = np.reshape(res, (res.shape[0], 1, res.shape[1]))
        pre = model.predict(res)
        res = np.append(res, [[pre[-1]]])
        res = np.reshape(res, (res.shape[0], 1))
    pre = scaler.inverse_transform(pre)

    return pre[-1]

# ========== MAAIN
# Out:
# Using TensorFlow backend.

# %%
# Main file loader
sub_fileDR = './data/submission.csv'
reg_batter_fileDR = './data/Regular_Season_Batter.csv'

submissionFile = pd.read_csv(sub_fileDR)
reg_batterFile = pd.read_csv(reg_batter_fileDR)

bat_id = submissionFile['batter_id'].unique()
bat_id = bat_id.tolist()

Month_data = mkMonthData()
mon_data_bat_id = Month_data['batter_id'].unique()

modelOPS = get_OPS_model(reg_batterFile)

main_col = [
        'avg','AB','R','H',
        '2B','3B','HR','RBI','BB',
        'HBP','SO','GDP','SLG'
        ]
# Out:
# C:\Users\goddo\Anaconda3\lib\site-packages\ipykernel_launcher.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users
200
# 241/241 [==============================] - 0s 87us/step - loss: 0.0025
# Epoch 194/200
# 241/241 [==============================] - 0s 83us/step - loss: 0.0026
# Epoch 195/200
# 241/241 [==============================] - 0s 79us/step - loss: 0.0028
# Epoch 196/200
# 241/241 [==============================] - 0s 79us/step - loss: 0.0027
# Epoch 197/200
# 241/241 [==============================] - 0s 83us/step - loss: 0.0025
# Epoch 198/200
# 241/241 [==============================] - 0s 83us/step - loss: 0.0025
# Epoch 199/200
# 241/241 [==============================] - 0s 87us/step - loss: 0.0026
# Epoch 200/200
# 241/241 [==============================] - 0s 91us/step - loss: 0.0025

# %%
bat_id = [1,63,64,65]

# %%
for eachId in bat_id:
    if eachId in mon_data_bat_id:
        

        # day_by_day 데이터 예측 또는 평균 값 도출 후 OPS 예측
        look_back = 1
        
        nptf = Month_data.loc[Month_data['batter_id'] == eachId]
        eachPlayer_record = []
        for col in main_col: 
            if len(nptf) > 20:
                res = predcit_next_DBD(nptf, col, look_back)
                res = res.item(0)
                eachPlayer_record.append(res)
            else:
                res = nptf[col].mean()
                res = res.item(0)
                eachPlayer_record.append(res)
        
        # ToDo LIST
        # eachPlayer_record -> reshape 과정 거쳐야 함
        print(eachPlayer_record)
        final_pre = pd.DataFrame(np.array(eachPlayer_record), columns=main_col)
        final_pre['BABIP'] = get_BABIP(final_pre)
        final_PL_OPS = modelOPS.predict(final_pre)
        print('eachId: ', eachId, "OPS: ", final_PL_OPS)



    
    else:
        # Not sure
        nptf = reg_batterFile.loc[reg_batterFile['batter_id'] == eachId]
        final_PL_OPS = nptf.iloc[-1]
        print(final_PL_OPS)
# Out:
# Epoch 1/5
#  - 1s - loss: 0.3061
# Epoch 2/5
#  - 0s - loss: 0.2609
# Epoch 3/5
#  - 0s - loss: 0.2182
# Epoch 4/5
#  - 0s - loss: 0.1797
# Epoch 5/5
#  - 0s - loss: 0.1455
# Epoch 1/5
#  - 1s - loss: 0.1985
# Epoch 2/5
#  - 0s - loss: 0.1743
# Epoch 3/5
#  - 0s - loss: 0.1524
# Epoch 4/5
#  - 0s - loss: 0.1341
# Epoch 5/5
#  - 0s - loss: 0.1194
# Epoch 1/5
#  - 1s - loss: 0.1427
# Epoch 2/5
#  - 0s - loss: 0.1291
# Epoch 3/5
#  - 0s - loss: 0.1162
# Epoch 4/5
#  - 0s - loss: 0.1071
# Epoch 5/5
#  - 0s - loss: 0.0999
# Epoch 1/5
#  - 1s - loss: 0.1254
# Epoch 2/5
#  - 0s - loss: 0.1090
# Epoch 3/5
#  - 0s - loss: 0.0968
# Epoch 4/5
#  - 0s - loss: 0.0868
# Epoch 5/5
#  - 0s - loss: 0.0794
# Epoch 1/5
#  - 1s - loss: 0.0978
# Epoch 2/5
#  - 0s - loss: 0.0926
# Epoch 3/5
#  - 0s - loss: 0.0887
# Epoch 4/5
#  - 0s - loss: 0.0848
# Epoch 5/5
#  - 0s - loss: 0.0813
# Epoch 1/5
#  - 1s - loss: 0.1875
# Epoch 2/5
#  - 0s - loss: 0.1792
# Epoch 3/5
#  - 0s - loss: 0.1722
# Epoch 4/5
#  - 0s - loss: 0.1663
# Epoch 5/5
#  - 0s - loss: 0.1607
# Epoch 1/5
#  - 1s - loss: 0.0751
# Epoch 2/5
#  - 0s - loss: 0.0727
# Epoch 3/5
#  - 0s - loss: 0.0708
# Epoch 4/5
#  - 0s - loss: 0.0702
# Epoch 5/5
#  - 0s - loss: 0.0684
# Epoch 1/5
#  - 1s - loss: 0.0758
# Epoch 2/5
#  - 0s - loss: 0.0700
# Epoch 3/5
#  - 0s - loss: 0.0644
# Epoch 4/5
#  - 0s - loss: 0.0604
# Epoch 5/5
#  - 0s - loss: 0.0573
# Epoch 1/5
#  - 1s - loss: 0.1571
# Epoch 2/5
#  - 0s - loss: 0.1371
# Epoch 3/5
#  - 0s - loss: 0.1223
# Epoch 4/5
#  - 0s - loss: 0.1082
# Epoch 5/5
#  - 0s - loss: 0.0982
# Epoch 1/5
#  - 1s - loss: 0.0837
# Epoch 2/5
#  - 0s - loss: 0.0788
# Epoch 3/5
#  - 0s - loss: 0.0742
# Epoch 4/5
#  - 0s - loss: 0.0707
# Epoch 5/5
#  - 0s - loss: 0.0692
# Epoch 1/5
#  - 1s - loss: 0.1888
# Epoch 2/5
#  - 0s - loss: 0.1648
# Epoch 3/5
#  - 0s - loss: 0.1465
# Epoch 4/5
#  - 0s - loss: 0.1289
# Epoch 5/5
#  - 0s - loss: 0.1162
# Epoch 1/5
#  - 2s - loss: 0.1371
# Epoch 2/5
#  - 0s - loss: 0.1305
# Epoch 3/5
#  - 0s - loss: 0.1230
# Epoch 4/5
#  - 0s - loss: 0.1181
# Epoch 5/5
#  - 0s - loss: 0.1147
# Epoch 1/5
#  - 2s - loss: 0.2423
# Epoch 2/5
#  - 0s - loss: 0.2110
# Epoch 3/5
#  - 0s - loss: 0.1831
# Epoch 4/5
#  - 0s - loss: 0.1598
# Epoch 5/5
#  - 0s - loss: 0.1386
# [0.08272944390773773, 13.07705020904541, 2.5526793003082275, 4.088769435882568, 0.37458208203315735, 0.19039151072502136, 0.17837175726890564, 1.5191799402236938, 1.643202781677246, 0.3058103621006012, 2.9386019706726074, 0.2763994038105011, 0.10688129812479019]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_blocks(blocks, axes)
#    4856                 blocks = [make_block(values=blocks[0],
# -> 4857                                      placement=slice(0, len(axes[0])))]
#    4858
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3204
# -> 3205     return klass(values, ndim=ndim, placement=placement)
#    3206
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in __init__(self, values, placement, ndim)
#     124                 'Wrong number of items passed {val}, placement implies '
# --> 125                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#     126
#
# ValueError: Wrong number of items passed 1, placement implies 13
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-4fa6add25a63> in <module>
#      22         # eachPlayer_record -> reshape 과정 거쳐야 함
#      23         print(eachPlayer_record)
# ---> 24         final_pre = pd.DataFrame(np.array(eachPlayer_record), columns=main_col)
#      25         final_pre['BABIP'] = get_BABIP(final_pre)
#      26         final_PL_OPS = modelOPS.predict(final_pre)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     377             else:
#     378                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 379                                          copy=copy)
#     380         elif isinstance(data, (list, types.GeneratorType)):
#     381             if isinstance(data, types.GeneratorType):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     534             values = maybe_infer_to_datetimelike(values)
#     535
# --> 536         return create_block_manager_from_blocks([values], [columns, index])
#     537
#     538     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_blocks(blocks, axes)
#    4864         blocks = [getattr(b, 'values', b) for b in blocks]
#    4865         tot_items = sum(b.shape[0] for b in blocks)
# -> 4866         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    4867
#    4868
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in construction_error(tot_items, block_shape, axes, e)
#    4841         raise ValueError("Empty data passed with indices specified.")
#    4842     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4843         passed, implied))
#    4844
#    4845
#
# ValueError: Shape of passed values is (1, 13), indices imply (13, 13)

# %%
eachId = 1
eachPlayer_record = []
if eachId in mon_data_bat_id:
    # day_by_day 데이터 예측 또는 평균 값 도출 후 OPS 예측
    look_back = 1

    nptf = Month_data.loc[Month_data['batter_id'] == eachId]

    for col in main_col: 
        if len(nptf) > 20:
            res = predcit_next_DBD(nptf, col, look_back)
            res = res.item(0)
            eachPlayer_record.append(res)
        else:
            res = nptf[col].mean()
            res = res.item(0)
            eachPlayer_record.append(res)
# Out:
# Epoch 1/5
#  - 2s - loss: 0.2570
# Epoch 2/5
#  - 0s - loss: 0.2134
# Epoch 3/5
#  - 0s - loss: 0.1722
# Epoch 4/5
#  - 0s - loss: 0.1378
# Epoch 5/5
#  - 0s - loss: 0.1082
# Epoch 1/5
#  - 2s - loss: 0.1627
# Epoch 2/5
#  - 0s - loss: 0.1462
# Epoch 3/5
#  - 0s - loss: 0.1322
# Epoch 4/5
#  - 0s - loss: 0.1203
# Epoch 5/5
#  - 0s - loss: 0.1105
# Epoch 1/5
#  - 2s - loss: 0.1580
# Epoch 2/5
#  - 0s - loss: 0.1409
# Epoch 3/5
#  - 0s - loss: 0.1291
# Epoch 4/5
#  - 0s - loss: 0.1169
# Epoch 5/5
#  - 0s - loss: 0.1093
# Epoch 1/5
#  - 2s - loss: 0.1225
# Epoch 2/5
#  - 0s - loss: 0.1093
# Epoch 3/5
#  - 0s - loss: 0.0994
# Epoch 4/5
#  - 0s - loss: 0.0911
# Epoch 5/5
#  - 0s - loss: 0.0846
# Epoch 1/5
#  - 2s - loss: 0.0989
# Epoch 2/5
#  - 0s - loss: 0.0929
# Epoch 3/5
#  - 0s - loss: 0.0876
# Epoch 4/5
#  - 0s - loss: 0.0826
# Epoch 5/5
#  - 0s - loss: 0.0791
# Epoch 1/5
#  - 2s - loss: 0.1895
# Epoch 2/5
#  - 0s - loss: 0.1811
# Epoch 3/5
#  - 0s - loss: 0.1741
# Epoch 4/5
#  - 0s - loss: 0.1665
# Epoch 5/5
#  - 0s - loss: 0.1613
# Epoch 1/5
#  - 2s - loss: 0.0747
# Epoch 2/5
#  - 0s - loss: 0.0715
# Epoch 3/5
#  - 0s - loss: 0.0694
# Epoch 4/5
#  - 0s - loss: 0.0684
# Epoch 5/5
#  - 0s - loss: 0.0665
# Epoch 1/5
#  - 2s - loss: 0.0730
# Epoch 2/5
#  - 0s - loss: 0.0658
# Epoch 3/5
#  - 0s - loss: 0.0612
# Epoch 4/5
#  - 0s - loss: 0.0572
# Epoch 5/5
#  - 0s - loss: 0.0552
# Epoch 1/5
#  - 3s - loss: 0.1647
# Epoch 2/5
#  - 0s - loss: 0.1452
# Epoch 3/5
#  - 0s - loss: 0.1292
# Epoch 4/5
#  - 0s - loss: 0.1167
# Epoch 5/5
#  - 0s - loss: 0.1052
# Epoch 1/5
#  - 3s - loss: 0.0834
# Epoch 2/5
#  - 0s - loss: 0.0773
# Epoch 3/5
#  - 0s - loss: 0.0734
# Epoch 4/5
#  - 0s - loss: 0.0688
# Epoch 5/5
#  - 0s - loss: 0.0658
# Epoch 1/5
#  - 3s - loss: 0.1899
# Epoch 2/5
#  - 0s - loss: 0.1642
# Epoch 3/5
#  - 0s - loss: 0.1434
# Epoch 4/5
#  - 0s - loss: 0.1259
# Epoch 5/5
#  - 0s - loss: 0.1109
# Epoch 1/5
#  - 3s - loss: 0.1343
# Epoch 2/5
#  - 0s - loss: 0.1276
# Epoch 3/5
#  - 0s - loss: 0.1223
# Epoch 4/5
#  - 0s - loss: 0.1178
# Epoch 5/5
#  - 0s - loss: 0.1118
# Epoch 1/5
#  - 3s - loss: 0.1866
# Epoch 2/5
#  - 0s - loss: 0.1609
# Epoch 3/5
#  - 0s - loss: 0.1389
# Epoch 4/5
#  - 0s - loss: 0.1209
# Epoch 5/5
#  - 0s - loss: 0.1088

# %%
# ToDo LIST
# eachPlayer_record -> reshape 과정 거쳐야 함
test1 = eachPlayer_record.copy()
print(test1)
print(len(test1))
print('====================================')
print(main_col)
print(len(main_col))

test1 = np.reshape(test1, (13,1))
final_pre = pd.DataFrame(np.array(test1), columns=main_col)
'''
final_pre['BABIP'] = get_BABIP(final_pre)
final_PL_OPS = modelOPS.predict(final_pre)
print('eachId: ', eachId, "OPS: ", final_PL_OPS)
'''
# else:
#     # Not sure
#     nptf = reg_batterFile.loc[reg_batterFile['batter_id'] == eachId]
#     final_PL_OPS = nptf.iloc[-1]
#     print(final_PL_OPS)
# Out:
# [0.0887807235121727, 12.52828598022461, 2.114022731781006, 3.5108652114868164, 0.4109276831150055, 0.17320385575294495, 0.17835500836372375, 1.8586024045944214, 1.5541234016418457, 0.25795191526412964, 3.0047929286956787, 0.2286590337753296, 0.13135232031345367]
# 13
# ====================================
# ['avg', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'HBP', 'SO', 'GDP', 'SLG']
# 13
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_blocks(blocks, axes)
#    4856                 blocks = [make_block(values=blocks[0],
# -> 4857                                      placement=slice(0, len(axes[0])))]
#    4858
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3204
# -> 3205     return klass(values, ndim=ndim, placement=placement)
#    3206
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in __init__(self, values, placement, ndim)
#     124                 'Wrong number of items passed {val}, placement implies '
# --> 125                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#     126
#
# ValueError: Wrong number of items passed 1, placement implies 13
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-ef9fb3b3b0eb> in <module>
#       9
#      10 test1 = np.reshape(test1, (13,1))
# ---> 11 final_pre = pd.DataFrame(np.array(test1), columns=main_col)
#      12 '''
#      13 final_pre['BABIP'] = get_BABIP(final_pre)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     377             else:
#     378                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 379                                          copy=copy)
#     380         elif isinstance(data, (list, types.GeneratorType)):
#     381             if isinstance(data, types.GeneratorType):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     534             values = maybe_infer_to_datetimelike(values)
#     535
# --> 536         return create_block_manager_from_blocks([values], [columns, index])
#     537
#     538     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_blocks(blocks, axes)
#    4864         blocks = [getattr(b, 'values', b) for b in blocks]
#    4865         tot_items = sum(b.shape[0] for b in blocks)
# -> 4866         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    4867
#    4868
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in construction_error(tot_items, block_shape, axes, e)
#    4841         raise ValueError("Empty data passed with indices specified.")
#    4842     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4843         passed, implied))
#    4844
#    4845
#
# ValueError: Shape of passed values is (1, 13), indices imply (13, 13)
